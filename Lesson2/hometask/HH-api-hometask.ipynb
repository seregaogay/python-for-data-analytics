# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/da-python/python-for-data-analytics/blob/main/Lesson2/hometask/HH-api-hometask.ipynb)

# %% [markdown]
# # Задание
# * Скачать все вакансии СБЕРа с ХХ (у апи есть ограничение в 2000, а также captcha подумайте как их можно обойти)
# * Извлеките все описания этих вакансий
# * Создайте аналогичный vacancy DataFrame только добавьте поле skills
# * Переведите даты публикаций в datetime
# * Постройте график опубликованных вакансий по датам
# * Переведите даты в дни недели, и определите день недели, в который больше всего публикуют вакансий
# * Найдите те вакансии с использованием python, которые вам интересны
# * Определите по полю skills какие навыки больше всего востребованы для этих вакансий
# * Постройте график наиболее востребованных навыков для аналитика данных

# %% [markdown]
# https://github.com/hhru/api

# %%
import requests
import json
from tqdm.auto import tqdm
from collections import defaultdict
import pickle
import pandas as pd

# %%
sber = '3529'
page = 1
num_per_page = 100
url = f'https://api.hh.ru/vacancies?employer_id={sber}&page={page}&per_page={num_per_page}'

# %%
res = requests.get(url)

# %%
print(res)
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'alternate_url': 'https://hh.ru/search/vacancy?control_flag=vacancyBlacklistJoinEnabled%3ATrue&employer_id=3529&enable_snippets=true&items_on_page=100&page=1',
#  'arguments': None,
#  'clusters': None,
#  'found': 3994,
#  'items': [{'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/68011820/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68011820',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68011820',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-21T08:23:59+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '68011820',
#    'insider_interview': None,
#    'name': 'Стажер DevOps',
#    'premium': False,
#    'published_at': '2022-07-21T08:23:59+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Базовые знание и умение работать в Linux. Знание основных bash команд. Навык разработки в любом ООП языке. Умение читать логи...',
#     'responsibility': 'Groovy (организация кода в классах). Ansible (настройка и написание скриптов). Docker. OpenShift.'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/68011820?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': None,
#     'city': 'Ростов-на-Дону',
#     'description': None,
#     'id': '6833208',
#     'lat': 47.2224566,
#     'lng': 39.718803,
#     'metro': None,
#     'metro_stations': [],
#     'raw': 'Ростов-на-Дону',
#     'street': None},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67849098/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67849098',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67849098',
#    'archived': False,
#    'area': {'id': '76',
#     'name': 'Ростов-на-Дону',
#     'url': 'https://api.hh.ru/areas/76'},
#    'contacts': None,
#    'created_at': '2022-07-18T08:54:50+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67849098',
#    'insider_interview': None,
#    'name': 'Старший клиентский менеджер',
#    'premium': False,
#    'published_at': '2022-07-18T08:54:50+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 56000, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Предлагать продукты и услуги Сбера. Консультировать клиентов по возникающим вопросам. Помогать клиентам оформлять услуги и...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67849098?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67470523/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67470523',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67470523',
#    'archived': False,
#    'area': {'id': '96', 'name': 'Ижевск', 'url': 'https://api.hh.ru/areas/96'},
#    'contacts': None,
#    'created_at': '2022-07-04T17:18:35+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67470523',
#    'insider_interview': None,
#    'name': 'Менеджер по работе с ключевыми клиентами малого бизнеса',
#    'premium': False,
#    'published_at': '2022-07-04T17:18:35+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 64000, 'gross': True, 'to': None},
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'snippet': {'requirement': 'Высшее или неполное высшее образование. Опыт в сфере продаж корпоративным клиентам. Понимание основ ведения бизнеса. Умение выстраивать отношения с людьми. ',
#     'responsibility': 'Развивать бизнес клиентов из закрепленной базы, предлагая продукты и услуги Сбера. Проводить переговоры с клиентами на территории компаний-партнеров. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67470523?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '32',
#     'city': 'Москва',
#     'description': None,
#     'id': '6080840',
#     'lat': 55.740426,
#     'lng': 37.532071,
#     'metro': None,
#     'metro_stations': [],
#     'raw': 'Москва, Кутузовский проспект, 32',
#     'street': 'Кутузовский проспект'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67908794/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67908794',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67908794',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-19T11:32:28+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67908794',
#    'insider_interview': None,
#    'name': 'Стажер Sber AI Lab',
#    'premium': False,
#    'published_at': '2022-07-19T11:32:28+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 55000, 'gross': True, 'to': 57000},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Имеешь хорошие знания математики и алгоритмов. Умеешь писать на python и хорошо знаком со стандартными библиотеками(pandas, numpy, sklearn, pytorch...',
#     'responsibility': 'У тебя есть публикации в ведущих научных конференциях и журналах. Участвовал в DS соревнованиях Kaggle и пр.. Любишь изучать новые...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67908794?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '32',
#     'city': 'Москва',
#     'description': None,
#     'id': '823806',
#     'lat': 55.740421,
#     'lng': 37.532071,
#     'metro': {'lat': 55.740833,
#      'line_id': '95',
#      'line_name': 'МЦК',
#      'lng': 37.533333,
#      'station_id': '95.536',
#      'station_name': 'Кутузовская'},
#     'metro_stations': [{'lat': 55.740833,
#       'line_id': '95',
#       'line_name': 'МЦК',
#       'lng': 37.533333,
#       'station_id': '95.536',
#       'station_name': 'Кутузовская'}],
#     'raw': 'Москва, Кутузовский проспект, 32',
#     'street': 'Кутузовский проспект'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67536591/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67536591',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67536591',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-06T12:41:40+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67536591',
#    'insider_interview': None,
#    'name': 'Ведущий конструктор в Центр Робототехники',
#    'premium': False,
#    'published_at': '2022-07-06T12:41:40+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 270000, 'gross': True, 'to': 300000},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее инженерное образование в области машиностроения или приборостроения. Опыт проектирования – не менее 5 лет. Опыт управления проектированием и разработкой - не...',
#     'responsibility': 'Выбор и обоснование кинематических схем роботов/узлов роботов, выбор принципиальных конструктивных решений. Проведение кинематических, энергетических, прочностных и других расчетов. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67536591?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67994168/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67994168',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67994168',
#    'archived': False,
#    'area': {'id': '76',
#     'name': 'Ростов-на-Дону',
#     'url': 'https://api.hh.ru/areas/76'},
#    'contacts': None,
#    'created_at': '2022-07-20T15:27:17+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67994168',
#    'insider_interview': None,
#    'name': 'QA - инженер',
#    'premium': False,
#    'published_at': '2022-07-20T15:27:17+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Хорошее понимание процесса тестирования ПО. Опыт проведения функционального и интеграционного тестирования от года. Опыт работы с багтрекенговыми системами и системами...',
#     'responsibility': 'Проведение функционального и регрессионного тестирования. Написание тестовой документации (тест-кейсов, чек-листов). Заведение и мониторинг дефектов. Подготовка тестовых данных. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67994168?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '10',
#     'city': 'Москва',
#     'description': None,
#     'id': '146841',
#     'lat': 55.695905,
#     'lng': 37.625361,
#     'metro': {'lat': 55.70961,
#      'line_id': '9',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'lng': 37.622569,
#      'station_id': '9.142',
#      'station_name': 'Тульская'},
#     'metro_stations': [{'lat': 55.70961,
#       'line_id': '9',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'lng': 37.622569,
#       'station_id': '9.142',
#       'station_name': 'Тульская'}],
#     'raw': 'Москва, Новоданиловская набережная, 10',
#     'street': 'Новоданиловская набережная'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67353952/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67353952',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67353952',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-06-29T22:39:43+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67353952',
#    'insider_interview': None,
#    'name': 'Аналитик',
#    'premium': False,
#    'published_at': '2022-06-29T22:39:43+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее образование. Владение MS Excel на уровне продвинутого пользователя (обработка больших массивов данных, знание сводных таблиц и т.д.). ',
#     'responsibility': 'Сбор и обработка больших массивов данных и построение отчетных форм. Подготовка стандартных и нестандартных выгрузок по запросам руководителя. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67353952?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67807387/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67807387',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67807387',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-15T12:34:24+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67807387',
#    'insider_interview': None,
#    'name': 'Junior Frontend Developer',
#    'premium': False,
#    'published_at': '2022-07-15T12:34:24+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Понимание современного стека WEB-разработки. Понимание основных паттернов проектирования и структур данных. Знание Typescript или JavaScript (мы используем TypeScript). ',
#     'responsibility': 'Под руководством наставника проектировать и разрабатывать новые фичи, развивать существующие одностраничные приложения на React. Писать тесты под свой код (Cypress). '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67807387?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67409350/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67409350',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67409350',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-01T14:52:53+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67409350',
#    'insider_interview': None,
#    'name': 'Секретарь',
#    'premium': False,
#    'published_at': '2022-07-01T14:52:53+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Опыт работы ассистентом руководителя от 3х лет. Опыт ведение электронного документооборота. Опыт ведение календаря руководителя. Умение работать в режиме...',
#     'responsibility': 'Ведение документооборота, работа с входящей и исходящей корреспонденцией. Прием и распределение входящих звонков. Планирование, организация и координация рабочего дня руководителя. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67409350?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67489007/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67489007',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67489007',
#    'archived': False,
#    'area': {'id': '72', 'name': 'Пермь', 'url': 'https://api.hh.ru/areas/72'},
#    'contacts': None,
#    'created_at': '2022-07-22T11:02:56+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67489007',
#    'insider_interview': None,
#    'name': 'Менеджер по работе с ключевыми клиентами малого бизнеса',
#    'premium': False,
#    'published_at': '2022-07-22T11:02:56+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 64000, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее или неполное высшее образование. Опыт в сфере продаж корпоративным клиентам. Понимание основ ведения бизнеса. Умение выстраивать отношения с людьми. ',
#     'responsibility': 'Развивать бизнес клиентов из закрепленной базы, предлагая продукты и услуги Сбера. Проводить переговоры с клиентами на территории компаний-партнеров. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67489007?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '4/1',
#     'city': 'Омск',
#     'description': None,
#     'id': '158060',
#     'lat': 54.984569,
#     'lng': 73.385882,
#     'metro': None,
#     'metro_stations': [],
#     'raw': 'Омск, улица маршала Жукова, 4/1',
#     'street': 'улица маршала Жукова'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/54641086/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54641086',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54641086',
#    'archived': False,
#    'area': {'id': '68', 'name': 'Омск', 'url': 'https://api.hh.ru/areas/68'},
#    'contacts': None,
#    'created_at': '2022-06-26T07:31:47+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '54641086',
#    'insider_interview': None,
#    'name': 'Менеджер по работе с ключевыми клиентами малого бизнеса',
#    'premium': False,
#    'published_at': '2022-06-26T07:31:47+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 74200, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее или неполное высшее образование. Опыт в сфере продаж корпоративным клиентам. Понимание основ ведения бизнеса. Умение выстраивать отношения с людьми. ',
#     'responsibility': 'Развивать бизнес клиентов из закрепленной базы, предлагая продукты и услуги Сбера. Проводить переговоры с клиентами на территории компаний-партнеров. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/54641086?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67338661/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67338661',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67338661',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-06-29T13:19:22+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67338661',
#    'insider_interview': None,
#    'name': 'Финансовый менеджер/аналитик',
#    'premium': False,
#    'published_at': '2022-06-29T13:19:22+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Оконченное высшее образование по профилю математика, экономика или финансы. Опыт работы в финансах/оценке инвестиций или проектов, планово-экономическом подразделении...',
#     'responsibility': 'Участие в процессах бизнес-планирования (PnL, CF). Подготовка и анализ управленческой отчетности (план-факт анализ, прогноз исполнения и пр.). '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67338661?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': None,
#     'city': 'Ожерелье',
#     'description': None,
#     'id': '11319555',
#     'lat': 54.7930636,
#     'lng': 38.2661448,
#     'metro': None,
#     'metro_stations': [],
#     'raw': 'Ожерелье',
#     'street': None},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67858166/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67858166',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67858166',
#    'archived': False,
#    'area': {'id': '2030',
#     'name': 'Ожерелье',
#     'url': 'https://api.hh.ru/areas/2030'},
#    'contacts': None,
#    'created_at': '2022-07-18T11:07:17+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67858166',
#    'insider_interview': None,
#    'name': 'Старший менеджер по обслуживанию',
#    'premium': False,
#    'published_at': '2022-07-18T11:07:17+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 53600, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Владеешь программами Microsoft Office, Outlook. Готов к работе, предполагающей ежедневное проведение...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Осуществлять операции по обслуживанию клиентов. Проводить кассовые операции: прием, выдача, обмен денег. Предлагать продукты и...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67858166?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/66697224/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66697224',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66697224',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-18T14:19:03+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '66697224',
#    'insider_interview': None,
#    'name': 'Специалист по договорам',
#    'premium': False,
#    'published_at': '2022-07-18T14:19:03+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее образование. Продвинутые навыки и знание профильных MS Excel, Power Point, Access. Умение работать с большим объемом информации. ',
#     'responsibility': 'Ведение переговоров в рамках заключения договоров между ДЗО и ПАО Сбербанк. Согласование договоров между ДЗО и ПАО Сбербанк. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/66697224?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '34',
#     'city': 'Краснодар',
#     'description': None,
#     'id': '918965',
#     'lat': 45.022322,
#     'lng': 38.972295,
#     'metro': None,
#     'metro_stations': [],
#     'raw': 'Краснодар, Центральный микрорайон, Красноармейская улица, 34',
#     'street': 'Центральный микрорайон, Красноармейская улица'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67516174/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67516174',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67516174',
#    'archived': False,
#    'area': {'id': '53',
#     'name': 'Краснодар',
#     'url': 'https://api.hh.ru/areas/53'},
#    'contacts': None,
#    'created_at': '2022-07-05T22:33:33+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67516174',
#    'insider_interview': None,
#    'name': 'Менеджер по маркетингу и коммуникациям',
#    'premium': False,
#    'published_at': '2022-07-05T22:33:33+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее образование (маркетинг\\пиар\\журналистика). Опыт работы в области рекламы и маркетинга от 2-х лет. Навыки управления проектами. ',
#     'responsibility': 'Участие в разработке и реализации маркетинговых активностей для клиентов и/или сотрудников банка. Написание и редактура релизов, статей, приветственных писем...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67516174?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': None,
#     'city': 'Домодедово',
#     'description': None,
#     'id': '7016055',
#     'lat': 55.4363283,
#     'lng': 37.7664984,
#     'metro': None,
#     'metro_stations': [],
#     'raw': 'Домодедово',
#     'street': None},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67779542/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67779542',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67779542',
#    'archived': False,
#    'area': {'id': '2025',
#     'name': 'Домодедово',
#     'url': 'https://api.hh.ru/areas/2025'},
#    'contacts': None,
#    'created_at': '2022-07-14T15:04:14+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67779542',
#    'insider_interview': None,
#    'name': 'Старший клиентский менеджер',
#    'premium': False,
#    'published_at': '2022-07-14T15:04:14+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 86000, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Предлагать продукты и услуги Сбера. Консультировать клиентов по возникающим вопросам. Помогать клиентам оформлять услуги и...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67779542?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67366110/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67366110',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67366110',
#    'archived': False,
#    'area': {'id': '2039',
#     'name': 'Люберцы',
#     'url': 'https://api.hh.ru/areas/2039'},
#    'contacts': None,
#    'created_at': '2022-07-21T09:01:33+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67366110',
#    'insider_interview': None,
#    'name': 'Подсобный рабочий',
#    'premium': False,
#    'published_at': '2022-07-21T09:01:33+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 55000, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Исполнительность, ответственность. Стрессоустойчивость. Физическая выносливость.',
#     'responsibility': 'Прием ТМЦ на склад. Погрузочно-разгрузочные работы. Сортировка, укладка, переноска, фасовка товара. Выполнение подсобных, вспомогательных работ.'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67366110?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/68002091/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68002091',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68002091',
#    'archived': False,
#    'area': {'id': '76',
#     'name': 'Ростов-на-Дону',
#     'url': 'https://api.hh.ru/areas/76'},
#    'contacts': None,
#    'created_at': '2022-07-20T19:19:21+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '68002091',
#    'insider_interview': None,
#    'name': 'Старший специалист отдела строительного контроля',
#    'premium': False,
#    'published_at': '2022-07-20T19:19:21+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 87000, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее инженерное образование (в приоритете специальность «промышленное и гражданское строительство»). Опыт получения исходно-разрешительной и правоустанавливающей документации (ГПЗУ, согласований о...',
#     'responsibility': 'Проводить экспертизу исходно-разрешительной документации. Анализировать участников строительства. Оценивать сроки и стоимость реализации проектов. Выезжать на объект строительства для осмотра...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/68002091?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': None,
#     'city': 'Томск',
#     'description': None,
#     'id': '7365902',
#     'lat': 56.4845804,
#     'lng': 84.9481582,
#     'metro': None,
#     'metro_stations': [],
#     'raw': 'Томск',
#     'street': None},
#    'adv_response_url': 'https://api.hh.ru/vacancies/55855276/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55855276',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55855276',
#    'archived': False,
#    'area': {'id': '90', 'name': 'Томск', 'url': 'https://api.hh.ru/areas/90'},
#    'contacts': None,
#    'created_at': '2022-07-18T09:36:23+0300',
#    'department': {'id': '3529-3529-stat', 'name': 'Сбер. Начало карьеры'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '55855276',
#    'insider_interview': None,
#    'name': 'Клиентский менеджер прямых продаж',
#    'premium': False,
#    'published_at': '2022-07-18T09:36:23+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 56300, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': None,
#     'responsibility': 'Выезжать к клиентам на индивидуальные консультации. Проводить презентации сервисов Сбера на территории компаний-партнеров. Предлагать сервисы Сбера и помогать с...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/55855276?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67577858/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67577858',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67577858',
#    'archived': False,
#    'area': {'id': '4',
#     'name': 'Новосибирск',
#     'url': 'https://api.hh.ru/areas/4'},
#    'contacts': None,
#    'created_at': '2022-07-07T13:56:34+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67577858',
#    'insider_interview': None,
#    'name': 'Стажер Data Science',
#    'premium': False,
#    'published_at': '2022-07-07T13:56:34+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Хорошо знаешь мат. статистику и теорию вероятностей. Разбираешься в Python/SAS/R и основных библиотеках анализа данных. Знаешь основы Data...',
#     'responsibility': 'Открываем набор 2022 на стажировку в DataScience Хаб в Управление валидации. Наша команда занимается оценкой и управлением модельного риска. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67577858?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '26А',
#     'city': 'Тольятти',
#     'description': None,
#     'id': '1240450',
#     'lat': 53.5583737698,
#     'lng': 49.2965355609,
#     'metro': None,
#     'metro_stations': [],
#     'raw': 'Тольятти, Транспортная улица, 26А',
#     'street': 'Транспортная улица'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/54422990/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54422990',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54422990',
#    'archived': False,
#    'area': {'id': '212',
#     'name': 'Тольятти',
#     'url': 'https://api.hh.ru/areas/212'},
#    'contacts': None,
#    'created_at': '2022-06-27T14:21:42+0300',
#    'department': {'id': '3529-3529-stat', 'name': 'Сбер. Начало карьеры'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '54422990',
#    'insider_interview': None,
#    'name': 'Специалист технической поддержки',
#    'premium': False,
#    'published_at': '2022-06-27T14:21:42+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': None, 'gross': True, 'to': 47300},
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'snippet': {'requirement': 'У тебя среднее специальное или высшее образование (ждем в том числе студентов последних курсов). Грамотная устная и письменная речь, четкая...',
#     'responsibility': 'Общаться с клиентами по телефону, e-mail, в чате, помогая им работать в онлайн-банке. Консультировать в случае сбоев и...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/54422990?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': None,
#     'city': 'Рыбное',
#     'description': None,
#     'id': '11281650',
#     'lat': 54.72568,
#     'lng': 39.513503,
#     'metro': None,
#     'metro_stations': [],
#     'raw': 'Рыбное',
#     'street': None},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67680226/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67680226',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67680226',
#    'archived': False,
#    'area': {'id': '1709',
#     'name': 'Рыбное',
#     'url': 'https://api.hh.ru/areas/1709'},
#    'contacts': None,
#    'created_at': '2022-07-12T08:40:02+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67680226',
#    'insider_interview': None,
#    'name': 'Старший клиентский менеджер',
#    'premium': False,
#    'published_at': '2022-07-12T08:40:02+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 62500, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Предлагать продукты и услуги Сбера. Консультировать клиентов по возникающим вопросам. Помогать клиентам оформлять услуги и...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67680226?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '32к1',
#     'city': 'Москва',
#     'description': None,
#     'id': '731097',
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'metro': {'lat': 55.740544,
#      'line_id': '4',
#      'line_name': 'Филевская',
#      'lng': 37.5341,
#      'station_id': '4.73',
#      'station_name': 'Кутузовская'},
#     'metro_stations': [{'lat': 55.740544,
#       'line_id': '4',
#       'line_name': 'Филевская',
#       'lng': 37.5341,
#       'station_id': '4.73',
#       'station_name': 'Кутузовская'},
#      {'lat': 55.740833,
#       'line_id': '95',
#       'line_name': 'МЦК',
#       'lng': 37.533333,
#       'station_id': '95.536',
#       'station_name': 'Кутузовская'}],
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'street': 'Кутузовский проспект'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67504369/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67504369',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67504369',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-05T14:33:23+0300',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67504369',
#    'insider_interview': None,
#    'name': 'Стажер Data scientist NLP',
#    'premium': False,
#    'published_at': '2022-07-05T14:33:23+0300',
#    'relations': [],
# ...
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67706800?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67715431/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67715431',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67715431',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-12T18:24:19+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67715431',
#    'insider_interview': None,
#    'name': 'Финансовый советник СберПервый',
#    'premium': False,
#    'published_at': '2022-07-12T18:24:19+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Специалист с высшим образованием в сфере финансов, экономики или бухгалтерии. Имеешь релевантный опыт работы в сфере продаж инвестиционных продуктов премиальному...',
#     'responsibility': 'Привлекать клиентов-инвесторов и вести действующую клиентскую базу. Работать в паре с персональным помощником, который будет помогать вести клиентскую базы...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67715431?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': '2Б',
#     'city': 'Воронеж',
#     'description': None,
#     'id': '559840',
#     'lat': 51.679258,
#     'lng': 39.268631,
#     'metro': None,
#     'metro_stations': [],
#     'raw': 'Воронеж, Минская улица, 2Б',
#     'street': 'Минская улица'},
#    'adv_response_url': 'https://api.hh.ru/vacancies/52427014/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/52427014',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=52427014',
#    'archived': False,
#    'area': {'id': '26',
#     'name': 'Воронеж',
#     'url': 'https://api.hh.ru/areas/26'},
#    'contacts': None,
#    'created_at': '2022-07-01T10:47:45+0300',
#    'department': {'id': '3529-3529-stat', 'name': 'Сбер. Начало карьеры'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '52427014',
#    'insider_interview': None,
#    'name': 'Специалист по телемаркетингу',
#    'premium': False,
#    'published_at': '2022-07-01T10:47:45+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 39000, 'gross': True, 'to': None},
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'snippet': {'requirement': 'Опыт: без опыта.',
#     'responsibility': 'Общаться с клиентами Сбера по телефону. Предлагать специально подобранные для клиентов продукты, услуги и сервисы Сбера.'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/52427014?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/68067583/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68067583',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68067583',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-22T14:09:54+0300',
#    'department': {'id': '3529-3529-lead',
#     'name': 'Сбер. Экспертам и руководителям'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '68067583',
#    'insider_interview': None,
#    'name': 'Дизайнер',
#    'premium': False,
#    'published_at': '2022-07-22T14:09:54+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Опыт работы продуктовым дизайнером/дизайнером по созданию интерфейсов B2B продуктов/графическим дизайнером/дизайнером презентаций от двух лет. ',
#     'responsibility': 'Разработка презентаций, инфографиков, логотипов. Работа с визуализацией данных. Развитие фирменного стиля и брендбука. Проектирование интерфейса от идеи до передачи в...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/68067583?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67981888/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67981888',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67981888',
#    'archived': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'contacts': None,
#    'created_at': '2022-07-20T11:59:41+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67981888',
#    'insider_interview': None,
#    'name': 'Data Scientist (Предиктивная аналитика)',
#    'premium': False,
#    'published_at': '2022-07-20T11:59:41+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Знание SQL - простые запросы, Joinы, агрегаты, группировки, вложенные запросы. Знакомство с форматами данных: сsv и разновидности, json, yaml, parquet, orc. ',
#     'responsibility': 'Участие в постановке задачи и ее бизнес применения. Построение, разработка и поддержка моделей машинного обучения (Python + Spark и тд). '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67981888?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': {'building': None,
#     'city': 'Климовск',
#     'description': None,
#     'id': '7647980',
#     'lat': 55.3749442,
#     'lng': 37.5389975,
#     'metro': None,
#     'metro_stations': [],
#     'raw': 'Климовск',
#     'street': None},
#    'adv_response_url': 'https://api.hh.ru/vacancies/67710111/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67710111',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67710111',
#    'archived': False,
#    'area': {'id': '2060',
#     'name': 'Климовск (Московская область)',
#     'url': 'https://api.hh.ru/areas/2060'},
#    'contacts': None,
#    'created_at': '2022-07-12T16:29:37+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67710111',
#    'insider_interview': None,
#    'name': 'Старший клиентский менеджер',
#    'premium': False,
#    'published_at': '2022-07-12T16:29:37+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 86000, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Предлагать продукты и услуги Сбера. Консультировать клиентов по возникающим вопросам. Помогать клиентам оформлять услуги и...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67710111?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67548995/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67548995',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67548995',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-06T17:06:09+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67548995',
#    'insider_interview': None,
#    'name': 'Редактор технических материалов',
#    'premium': False,
#    'published_at': '2022-07-06T17:06:09+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': None,
#     'responsibility': 'Редактировать материалы в соответствии с редполитикой. - Готовить пользовательские инструкции и другие информационные материалы (чек-листы, шпаргалки, новости, release notes). - '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67548995?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/66176148/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66176148',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66176148',
#    'archived': False,
#    'area': {'id': '95', 'name': 'Тюмень', 'url': 'https://api.hh.ru/areas/95'},
#    'contacts': None,
#    'created_at': '2022-07-06T07:52:05+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '66176148',
#    'insider_interview': None,
#    'name': 'Менеджер по работе с ключевыми клиентами малого бизнеса',
#    'premium': False,
#    'published_at': '2022-07-06T07:52:05+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': {'currency': 'RUR', 'from': 69600, 'gross': True, 'to': None},
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее или неполное высшее образование. Опыт в сфере продаж корпоративным клиентам. Понимание основ ведения бизнеса. Умение выстраивать отношения с людьми. ',
#     'responsibility': 'Развивать бизнес клиентов из закрепленной базы, предлагая продукты и услуги Сбера. Проводить переговоры с клиентами на территории компаний-партнеров. '},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/66176148?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []},
#   {'accept_temporary': False,
#    'address': None,
#    'adv_response_url': 'https://api.hh.ru/vacancies/67690176/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67690176',
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67690176',
#    'archived': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'contacts': None,
#    'created_at': '2022-07-12T11:13:55+0300',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'employer': {'alternate_url': 'https://hh.ru/employer/3529',
#     'id': '3529',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3914324.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG'},
#     'name': 'СБЕР',
#     'trusted': True,
#     'url': 'https://api.hh.ru/employers/3529',
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529'},
#    'has_test': False,
#    'id': '67690176',
#    'insider_interview': None,
#    'name': 'Кредитный инспектор в отдел администрирования кредитов',
#    'premium': False,
#    'published_at': '2022-07-12T11:13:55+0300',
#    'relations': [],
#    'response_letter_required': False,
#    'response_url': None,
#    'salary': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'snippet': {'requirement': 'Высшее образование по направлению: финансы или экономика. Опыт работы не менее 1 года в релевантной должности. Умение пользоваться необходимыми методическими...',
#     'responsibility': 'Организация подписания полного комплекта кредитно-обеспечительной документации со стороны Банка (включая документацию LMA), в т.ч. соглашений о работе со...'},
#    'sort_point_distance': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'url': 'https://api.hh.ru/vacancies/67690176?host=hh.ru',
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': []}],
#  'page': 1,
#  'pages': 20,
#  'per_page': 100}

# %%
vacancies = res.json()
num_pages = vacancies.get('pages')
num_pages

# %%
v = vacancies.get('items')

# %%
# v[0].get('')

# %%
vacancies.keys()
# Out:
# dict_keys(['id', 'premium', 'billing_type', 'relations', 'name', 'insider_interview', 'response_letter_required', 'area', 'salary', 'type', 'address', 'allow_messages', 'experience', 'schedule', 'employment', 'department', 'contacts', 'description', 'branded_description', 'vacancy_constructor_template', 'key_skills', 'accept_handicapped', 'accept_kids', 'archived', 'response_url', 'specializations', 'professional_roles', 'code', 'hidden', 'quick_responses_allowed', 'driver_license_types', 'accept_incomplete_resumes', 'employer', 'published_at', 'created_at', 'initial_created_at', 'negotiations_url', 'suitable_resumes_url', 'apply_alternate_url', 'has_test', 'test', 'alternate_url', 'working_days', 'working_time_intervals', 'working_time_modes', 'accept_temporary', 'languages'])

# %%
vacancies = res.json()
num_pages = vacancies.get('pages')
vacancy_ids = [el.get('id') for el in vacancies.get('items')]

# %%
vacancies.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'per_page', 'page', 'clusters', 'arguments', 'alternate_url'])

# %%
vnum  = vacancies.get('pages')

# %%
all_vacancy_ids= []
for i in tqdm(range(vnum)):
    url = f'https://api.hh.ru/vacancies?employer_id={sber}&page={i}&per_page={num_per_page}'
    res = requests.get(url)
    vacancies = res.json()
    vacancy_ids = [el.get('id') for el in vacancies.get('items')]
    all_vacancy_ids.extend(vacancy_ids)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
len(all_vacancy_ids)
# https://api.hh.ru/vacancies/66634517
# Out:
# 2000

# %%
vacs = []
for vac_id in tqdm(all_vacancy_ids):
  url = f'https://api.hh.ru/vacancies/{vac_id}'
  res = requests.get(url)
  vacs.append(res.json())
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
url = f'https://api.hh.ru/vacancies/{all_vacancy_ids[0]}'

# %%
res = requests.get(url)

# %%
res.json().keys()
# Out:
# dict_keys(['id', 'premium', 'billing_type', 'relations', 'name', 'insider_interview', 'response_letter_required', 'area', 'salary', 'type', 'address', 'allow_messages', 'experience', 'schedule', 'employment', 'department', 'contacts', 'description', 'branded_description', 'vacancy_constructor_template', 'key_skills', 'accept_handicapped', 'accept_kids', 'archived', 'response_url', 'specializations', 'professional_roles', 'code', 'hidden', 'quick_responses_allowed', 'driver_license_types', 'accept_incomplete_resumes', 'employer', 'published_at', 'created_at', 'initial_created_at', 'negotiations_url', 'suitable_resumes_url', 'apply_alternate_url', 'has_test', 'test', 'alternate_url', 'working_days', 'working_time_intervals', 'working_time_modes', 'accept_temporary', 'languages'])

# %%
res.json().get('key_skills')
# Out:
# [{'name': 'Spring Framework'},
#  {'name': 'PostgreSQL'},
#  {'name': 'Hibernate ORM'},
#  {'name': 'Git'},
#  {'name': 'Docker'}]

# %%
vacancies.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-0281da9790c0> in <module>()
# ----> 1 vacancies.info()
#
# AttributeError: 'dict' object has no attribute 'info'
